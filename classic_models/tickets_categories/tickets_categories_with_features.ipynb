# %% [markdown]
# # Ticket categories with features

# %% [markdown]
# # Импорты

# %%
# !pip install catboost
# !pip install pymorphy3
# !pip install optuna
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.10)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Requirement already satisfied: pymorphy3 in /usr/local/lib/python3.12/dist-packages (2.0.6)
# Requirement already satisfied: dawg2-python>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (75.2.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.8.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
import re

import joblib
import numpy as np
import optuna
import pandas as pd
import pymorphy3
from catboost import CatBoostClassifier
from nltk.corpus import stopwords
import nltk
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
)
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import SVC

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Загрузка и исследование данных

# %%
data = pd.read_excel('nerd_analytics_v25.xlsx', sheet_name='tickets')

# %%
chat_history = pd.read_excel('nerd_analytics_v25.xlsx', sheet_name='chat_history')

# %%
chat_history = chat_history[chat_history['ticket_id'].notna()][chat_history['role'] == 'client'][['ticket_id', 'message', 'created_at']].sort_values('created_at')
# Out:
# /tmp/ipykernel_16121/2863438230.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   chat_history = chat_history[chat_history['ticket_id'].notna()][chat_history['role'] == 'client'][['ticket_id', 'message', 'created_at']].sort_values('created_at')

# %%
chat_history = chat_history.drop_duplicates(subset='ticket_id', keep='first')

# %%
data = pd.merge(data.rename(columns={'id': 'ticket_id'}), chat_history[['ticket_id', 'message']], on='ticket_id', how='inner')

# %%
data = data[['ticket_id', 'message', 'product', 'priority', 'reopened_count', 'final_category']].copy()
data = data.dropna(subset=['message', 'final_category']).reset_index(drop=True)

data.shape
# Out:
# (3000, 6)

# %%
data.head()
# Out:
#                               ticket_id  \
# 0  ccbfdf1a-deaa-456b-b8c8-38d24a512664
# 1  84fd58d8-ce4c-4faa-897d-40f6f78cd699
# 2  a62f284b-f586-43b0-a31a-e974cdf265aa
# 3  e8273333-012f-440b-82bf-e07f36f49c22
# 4  605ea9ad-4877-4ed0-85a9-877ee438d3ca
#
#                                       message               product priority  \
# 0         Не могу найти счёт за прошлый месяц      платёжный сервис     high
# 1                   Дважды списали одну сумму        API интеграция     high
# 2               Менеджер был груб при общении  аналитический модуль      low
# 3                 Виджет чата не отображается        личный кабинет     high
# 4  Приложение не запускается после обновления        личный кабинет   medium
#
#    reopened_count    final_category
# 0               1  вопрос по оплате
# 1               0   запрос возврата
# 2               3  жалоба на сервис
# 3               0  технический сбой
# 4               0  технический сбой

# %%
data['final_category'].value_counts()
# Out:
# final_category
# технический сбой       413
# ошибка в данных        410
# консультация           389
# запрос возврата        388
# вопрос по оплате       370
# проблема с доступом    357
# жалоба на сервис       341
# запрос документов      332
# Name: count, dtype: int64

# %%
df1 = data.copy()

# %%
morph = pymorphy3.MorphAnalyzer()
russian_stopwords = stopwords.words('russian')
bad_stopwords = ['не', 'нет', 'ни', 'без']

russian_stopwords = [
    word for word in russian_stopwords
    if word not in bad_stopwords
]

CLEAN_TEXT_SOURCE = r'''
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", " ", text)
    text = re.sub(r"www\S+", " ", text)
    text = re.sub(r"@\w+", " ", text)
    text = re.sub(r"[^а-яa-zё\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    words = text.split()
    lemmas = []

    for word in words:
        if word not in russian_stopwords:
            lemma = morph.parse(word)[0].normal_form
            lemmas.append(lemma)

    return " ".join(lemmas)
'''

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", " ", text)
    text = re.sub(r"www\S+", " ", text)
    text = re.sub(r"@\w+", " ", text)
    text = re.sub(r"[^а-яa-zё\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    words = text.split()
    lemmas = []

    for word in words:
        if word not in russian_stopwords:
            lemma = morph.parse(word)[0].normal_form
            lemmas.append(lemma)

    return " ".join(lemmas)

df1['clean_message'] = df1['message'].apply(clean_text)
df1[['product', 'priority']] = df1[['product', 'priority']].fillna('unknown').astype(str)
df1[['reopened_count']] = df1[['reopened_count']].fillna(0)

# %%
RANDOM_STATE = 42

# %% [markdown]
# ## Подбираем модель и гиперпараметры для решения задачи через Optuna

# %%
cat_df = df1[['clean_message', 'product', 'priority', 'reopened_count', 'final_category']].copy()
X_all = cat_df.drop(columns=['final_category'])
y_all = cat_df['final_category']
groups_all = cat_df['clean_message']

N_SPLITS = 5
CV_RANDOM_STATES = [RANDOM_STATE, 101, 202, 303, 404]


def make_one_hot_encoder():
    try:
        return OneHotEncoder(handle_unknown='ignore', sparse_output=True)
    except TypeError:
        return OneHotEncoder(handle_unknown='ignore', sparse=True)


def build_features(train_part, valid_part, return_preprocessors=False):
    word_vectorizer = TfidfVectorizer(max_features=30000, ngram_range=(1, 2), min_df=2, max_df=0.95)
    char_vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), max_features=20000)
    encoder = make_one_hot_encoder()
    numeric_scaler = StandardScaler()

    X_train_word = word_vectorizer.fit_transform(train_part['clean_message'])
    X_valid_word = word_vectorizer.transform(valid_part['clean_message'])
    X_train_char = char_vectorizer.fit_transform(train_part['clean_message'])
    X_valid_char = char_vectorizer.transform(valid_part['clean_message'])
    X_train_cat = encoder.fit_transform(train_part[['product', 'priority']])
    X_valid_cat = encoder.transform(valid_part[['product', 'priority']])
    X_train_num = csr_matrix(numeric_scaler.fit_transform(train_part[['reopened_count']]))
    X_valid_num = csr_matrix(numeric_scaler.transform(valid_part[['reopened_count']]))

    X_train = hstack([X_train_word, X_train_char, X_train_cat, X_train_num])
    X_valid = hstack([X_valid_word, X_valid_char, X_valid_cat, X_valid_num])

    if return_preprocessors:
        preprocessors = {
            'word_vectorizer': word_vectorizer,
            'char_vectorizer': char_vectorizer,
            'encoder': encoder,
            'numeric_scaler': numeric_scaler,
        }
        return X_train, X_valid, preprocessors

    return X_train, X_valid


def build_model_and_params(trial):
    model_type = trial.suggest_categorical('model_type', ['SVC', 'LogReg', 'CatBoost'])

    if model_type == 'SVC':
        params = {
            'C': trial.suggest_float('svc_C', 0.1, 5.0, log=True),
            'kernel': trial.suggest_categorical('svc_kernel', ['linear', 'rbf']),
            'gamma': 'scale',
            'class_weight': trial.suggest_categorical('svc_class_weight', [None, 'balanced']),
        }
        return model_type, params

    if model_type == 'LogReg':
        params = {
            'C': trial.suggest_float('lr_C', 0.1, 10.0, log=True),
            'solver': trial.suggest_categorical('lr_solver', ['lbfgs', 'saga']),
            'class_weight': trial.suggest_categorical('lr_class_weight', [None, 'balanced']),
            'max_iter': 3000,
            'n_jobs': -1,
            'random_state': RANDOM_STATE,
        }
        return model_type, params

    params = {
        'iterations': trial.suggest_int('cb_iterations', 200, 900),
        'depth': trial.suggest_int('cb_depth', 4, 10),
        'learning_rate': trial.suggest_float('cb_learning_rate', 0.01, 0.2, log=True),
        'l2_leaf_reg': trial.suggest_int('cb_l2_leaf_reg', 1, 12),
        'random_strength': trial.suggest_float('cb_random_strength', 1.0, 10.0),
        'bagging_temperature': trial.suggest_float('cb_bagging_temperature', 0.0, 10.0),
        'border_count': trial.suggest_int('cb_border_count', 64, 255),
        'auto_class_weights': trial.suggest_categorical('cb_auto_class_weights', ['Balanced', None]),
    }
    return model_type, params


def make_model(model_type, model_params):
    if model_type == 'SVC':
        return SVC(**model_params)

    if model_type == 'LogReg':
        return LogisticRegression(**model_params)

    return CatBoostClassifier(
        **model_params,
        loss_function='MultiClass',
        eval_metric='TotalF1',
        random_state=RANDOM_STATE,
        task_type='GPU',
        verbose=False,
    )


def get_cv_scores(model_type, model_params, data, cv_random_states):
    fold_scores = []

    for cv_seed in cv_random_states:
        cv = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=cv_seed)

        for tr_fold_idx, val_fold_idx in cv.split(
            data.drop(columns=['final_category']),
            data['final_category'],
            groups=data['clean_message'],
        ):
            tr_part = data.iloc[tr_fold_idx]
            val_part = data.iloc[val_fold_idx]

            X_tr, X_val = build_features(tr_part, val_part)
            y_tr = tr_part['final_category']
            y_val = val_part['final_category']

            model = make_model(model_type, model_params)
            model.fit(X_tr, y_tr, verbose=False) if model_type == 'CatBoost' else model.fit(X_tr, y_tr)
            pred = model.predict(X_val).flatten() if model_type == 'CatBoost' else model.predict(X_val)

            fold_scores.append(f1_score(y_val, pred, average='macro'))

    return fold_scores


def objective(trial):
    model_type, model_params = build_model_and_params(trial)
    fold_scores = get_cv_scores(model_type, model_params, cat_df, CV_RANDOM_STATES)
    return float(np.mean(fold_scores))


sampler = optuna.samplers.TPESampler(seed=RANDOM_STATE)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=40)

print('BEST MEAN CV SCORE:')
print(study.best_value)
print('BEST PARAMS:')
print(study.best_params)
# Out:
# [I 2026-05-26 17:15:24,226] A new study created in memory with name: no-name-00b931d8-a3b1-4aa0-84e3-96f207afb359
# [I 2026-05-26 17:16:02,151] Trial 0 finished with value: 0.09506920440655647 and parameters: {'model_type': 'LogReg', 'lr_C': 1.5751320499779735, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:16:34,074] Trial 1 finished with value: 0.09295179074622541 and parameters: {'model_type': 'LogReg', 'lr_C': 8.706020878304859, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:17:06,125] Trial 2 finished with value: 0.086192477034802 and parameters: {'model_type': 'LogReg', 'lr_C': 0.38234752246751863, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:17:37,268] Trial 3 finished with value: 0.06864259452874964 and parameters: {'model_type': 'LogReg', 'lr_C': 1.0677482709481354, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:19:43,691] Trial 4 finished with value: 0.045826730812240264 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 766, 'cb_depth': 6, 'cb_learning_rate': 0.013399060561509796, 'cb_l2_leaf_reg': 9, 'cb_random_strength': 4.961372443656412, 'cb_bagging_temperature': 1.2203823484477883, 'cb_border_count': 159, 'cb_auto_class_weights': None}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:20:14,837] Trial 5 finished with value: 0.06873402688456609 and parameters: {'model_type': 'LogReg', 'lr_C': 1.0968217207529523, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:20:37,067] Trial 6 finished with value: 0.059968838034014045 and parameters: {'model_type': 'SVC', 'svc_C': 3.683296438423418, 'svc_kernel': 'rbf', 'svc_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:21:49,885] Trial 7 finished with value: 0.047833780024746704 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 450, 'cb_depth': 5, 'cb_learning_rate': 0.05082341959721458, 'cb_l2_leaf_reg': 2, 'cb_random_strength': 8.219772826786357, 'cb_bagging_temperature': 0.7455064367977082, 'cb_border_count': 253, 'cb_auto_class_weights': 'Balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:22:21,167] Trial 8 finished with value: 0.07588526132730548 and parameters: {'model_type': 'LogReg', 'lr_C': 2.8708753481954687, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:22:58,717] Trial 9 finished with value: 0.031899591501235156 and parameters: {'model_type': 'SVC', 'svc_C': 0.12822825454807552, 'svc_kernel': 'rbf', 'svc_class_weight': None}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:23:11,472] Trial 10 finished with value: 0.036444187620987695 and parameters: {'model_type': 'SVC', 'svc_C': 0.637043254433697, 'svc_kernel': 'linear', 'svc_class_weight': None}. Best is trial 0 with value: 0.09506920440655647.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:24:49,408] Trial 11 finished with value: 0.09284418310511779 and parameters: {'model_type': 'LogReg', 'lr_C': 6.536264082965733, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:25:21,581] Trial 12 finished with value: 0.09282445411596464 and parameters: {'model_type': 'LogReg', 'lr_C': 9.841670499136951, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:27:08,762] Trial 13 finished with value: 0.07168674350653143 and parameters: {'model_type': 'LogReg', 'lr_C': 0.18583114976096843, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.09506920440655647.
# [I 2026-05-26 17:27:40,926] Trial 14 finished with value: 0.09518084317735415 and parameters: {'model_type': 'LogReg', 'lr_C': 3.0465229181822853, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 14 with value: 0.09518084317735415.
# [I 2026-05-26 17:31:23,252] Trial 15 finished with value: 0.03737664105829972 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 216, 'cb_depth': 10, 'cb_learning_rate': 0.13622756644495823, 'cb_l2_leaf_reg': 12, 'cb_random_strength': 1.3022729644102489, 'cb_bagging_temperature': 9.855453830200455, 'cb_border_count': 70, 'cb_auto_class_weights': 'Balanced'}. Best is trial 14 with value: 0.09518084317735415.
# [I 2026-05-26 17:31:55,339] Trial 16 finished with value: 0.09582624436897724 and parameters: {'model_type': 'LogReg', 'lr_C': 2.8961603572682026, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 16 with value: 0.09582624436897724.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:34:21,111] Trial 17 finished with value: 0.09538492912184753 and parameters: {'model_type': 'LogReg', 'lr_C': 3.038943125965773, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 16 with value: 0.09582624436897724.
# [I 2026-05-26 17:48:48,053] Trial 18 finished with value: 0.035660202174940786 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 889, 'cb_depth': 10, 'cb_learning_rate': 0.013262582595226993, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 9.475849245820685, 'cb_bagging_temperature': 7.6770979884204085, 'cb_border_count': 80, 'cb_auto_class_weights': None}. Best is trial 16 with value: 0.09582624436897724.
# [I 2026-05-26 17:49:02,803] Trial 19 finished with value: 0.0687646897417577 and parameters: {'model_type': 'SVC', 'svc_C': 4.433639776495255, 'svc_kernel': 'linear', 'svc_class_weight': 'balanced'}. Best is trial 16 with value: 0.09582624436897724.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:51:27,750] Trial 20 finished with value: 0.09248194605507548 and parameters: {'model_type': 'LogReg', 'lr_C': 3.0458371202538017, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 16 with value: 0.09582624436897724.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:53:54,972] Trial 21 finished with value: 0.09400485771638424 and parameters: {'model_type': 'LogReg', 'lr_C': 3.170778918840918, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 16 with value: 0.09582624436897724.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:56:30,104] Trial 22 finished with value: 0.09590501991147304 and parameters: {'model_type': 'LogReg', 'lr_C': 2.1152300706303615, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 22 with value: 0.09590501991147304.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 17:59:06,696] Trial 23 finished with value: 0.09359312199035515 and parameters: {'model_type': 'LogReg', 'lr_C': 1.9334294851419451, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 22 with value: 0.09590501991147304.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:01:16,055] Trial 24 finished with value: 0.09622793698963505 and parameters: {'model_type': 'LogReg', 'lr_C': 3.9349286049156182, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:03:16,710] Trial 25 finished with value: 0.09487345999355828 and parameters: {'model_type': 'LogReg', 'lr_C': 4.626740818570083, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:05:19,614] Trial 26 finished with value: 0.05846733409181279 and parameters: {'model_type': 'LogReg', 'lr_C': 0.5169016749185937, 'lr_solver': 'saga', 'lr_class_weight': None}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:07:12,840] Trial 27 finished with value: 0.09466347052083778 and parameters: {'model_type': 'LogReg', 'lr_C': 5.147614611043033, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:07:52,050] Trial 28 finished with value: 0.030581278918816214 and parameters: {'model_type': 'SVC', 'svc_C': 0.11574159679765775, 'svc_kernel': 'rbf', 'svc_class_weight': None}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:09:07,762] Trial 29 finished with value: 0.04956843140175962 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 549, 'cb_depth': 4, 'cb_learning_rate': 0.18206368211504098, 'cb_l2_leaf_reg': 6, 'cb_random_strength': 1.040943911454403, 'cb_bagging_temperature': 4.231469403643498, 'cb_border_count': 243, 'cb_auto_class_weights': 'Balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:11:44,762] Trial 30 finished with value: 0.09474295533942674 and parameters: {'model_type': 'LogReg', 'lr_C': 1.8906893760899801, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:13:43,510] Trial 31 finished with value: 0.09525858478970432 and parameters: {'model_type': 'LogReg', 'lr_C': 4.908361327784984, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:16:24,943] Trial 32 finished with value: 0.09435870042827946 and parameters: {'model_type': 'LogReg', 'lr_C': 2.1824956500047654, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:19:01,477] Trial 33 finished with value: 0.0921393221167096 and parameters: {'model_type': 'LogReg', 'lr_C': 1.4070978961766716, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:21:22,404] Trial 34 finished with value: 0.08647729865528651 and parameters: {'model_type': 'LogReg', 'lr_C': 0.6747716169120556, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:23:32,860] Trial 35 finished with value: 0.09566198378398681 and parameters: {'model_type': 'LogReg', 'lr_C': 4.122654520982328, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2026-05-26 18:25:42,981] Trial 36 finished with value: 0.09534983684350641 and parameters: {'model_type': 'LogReg', 'lr_C': 4.018195867612568, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:26:49,881] Trial 37 finished with value: 0.04195252801453706 and parameters: {'model_type': 'LogReg', 'lr_C': 0.10685327573111018, 'lr_solver': 'saga', 'lr_class_weight': None}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:27:22,873] Trial 38 finished with value: 0.09616257114039031 and parameters: {'model_type': 'LogReg', 'lr_C': 2.0660501672384064, 'lr_solver': 'lbfgs', 'lr_class_weight': 'balanced'}. Best is trial 24 with value: 0.09622793698963505.
# [I 2026-05-26 18:29:04,457] Trial 39 finished with value: 0.03206316729828712 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 221, 'cb_depth': 8, 'cb_learning_rate': 0.046979692484144346, 'cb_l2_leaf_reg': 7, 'cb_random_strength': 4.810389702398632, 'cb_bagging_temperature': 4.856717350553467, 'cb_border_count': 173, 'cb_auto_class_weights': None}. Best is trial 24 with value: 0.09622793698963505.
# BEST MEAN CV SCORE:
# 0.09622793698963505
# BEST PARAMS:
# {'model_type': 'LogReg', 'lr_C': 3.9349286049156182, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}

# %% [markdown]
# ## Обучаем лучшую модель

# %%
best_params = dict(study.best_params)
best_model_type = best_params.pop('model_type')

if best_model_type == 'SVC':
    model_params = {
        'C': best_params['svc_C'],
        'kernel': best_params['svc_kernel'],
        'gamma': 'scale',
        'class_weight': best_params['svc_class_weight'],
    }
elif best_model_type == 'LogReg':
    model_params = {
        'C': best_params['lr_C'],
        'solver': best_params['lr_solver'],
        'class_weight': best_params['lr_class_weight'],
        'max_iter': 3000,
        'n_jobs': -1,
        'random_state': RANDOM_STATE,
    }
else:
    model_params = {
        'iterations': best_params['cb_iterations'],
        'depth': best_params['cb_depth'],
        'learning_rate': best_params['cb_learning_rate'],
        'l2_leaf_reg': best_params['cb_l2_leaf_reg'],
        'random_strength': best_params['cb_random_strength'],
        'bagging_temperature': best_params['cb_bagging_temperature'],
        'border_count': best_params['cb_border_count'],
        'auto_class_weights': best_params['cb_auto_class_weights'],
    }

cv_results = []
y_true_all = []
y_pred_all = []

for cv_seed in CV_RANDOM_STATES:
    cv = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=cv_seed)

    for fold, (tr_fold_idx, val_fold_idx) in enumerate(
        cv.split(X_all, y_all, groups=groups_all),
        start=1,
    ):
        tr_part = cat_df.iloc[tr_fold_idx]
        val_part = cat_df.iloc[val_fold_idx]

        X_tr, X_val = build_features(tr_part, val_part)
        y_tr = tr_part['final_category']
        y_val = val_part['final_category']

        model = make_model(best_model_type, model_params)
        model.fit(X_tr, y_tr, verbose=False) if best_model_type == 'CatBoost' else model.fit(X_tr, y_tr)
        pred = model.predict(X_val).flatten() if best_model_type == 'CatBoost' else model.predict(X_val)

        cv_results.append({
            'seed': cv_seed,
            'fold': fold,
            'accuracy': accuracy_score(y_val, pred),
            'macro_f1': f1_score(y_val, pred, average='macro'),
        })
        y_true_all.extend(y_val)
        y_pred_all.extend(pred)

cv_results_df = pd.DataFrame(cv_results)
y_true_cv = pd.Series(y_true_all, name='true')
y_pred_cv = pd.Series(y_pred_all, name='pred')

X_full, _, preprocessors = build_features(cat_df, cat_df, return_preprocessors=True)
best_model = make_model(best_model_type, model_params)
best_model.fit(X_full, y_all, verbose=False) if best_model_type == 'CatBoost' else best_model.fit(X_full, y_all)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=3.9349286049156182, class_weight='balanced', max_iter=3000,
#                    n_jobs=-1, random_state=42, solver='saga')

# %% [markdown]
# ## Результат на тестовой выборке

# %%
accuracy_mean = cv_results_df['accuracy'].mean()
accuracy_std = cv_results_df['accuracy'].std()
macro_f1_mean = cv_results_df['macro_f1'].mean()
macro_f1_std = cv_results_df['macro_f1'].std()

print(f'\nBest model type: {best_model_type}')
print(f'CV seeds: {CV_RANDOM_STATES}')
print(f'Accuracy: {accuracy_mean:.4f} +/- {accuracy_std:.4f}')
print(f'Macro F1: {macro_f1_mean:.4f} +/- {macro_f1_std:.4f}')
print('\nFOLD METRICS SUMMARY:\n')
print(cv_results_df[['accuracy', 'macro_f1']].describe())
print('\nCLASSIFICATION REPORT OVER ALL CV PREDICTIONS:\n')
print(classification_report(y_true_cv, y_pred_cv, zero_division=0))
print('\nCONFUSION MATRIX OVER ALL CV PREDICTIONS:\n')
print(confusion_matrix(y_true_cv, y_pred_cv))
# Out:
# Best model type: LogReg
# CV seeds: [42, 101, 202, 303, 404]
# Accuracy: 0.1569 +/- 0.1073
# Macro F1: 0.0962 +/- 0.0631
#
# FOLD METRICS SUMMARY:
#
#         accuracy   macro_f1
# count  25.000000  25.000000
# mean    0.156920   0.096228
# std     0.107338   0.063085
# min     0.001957   0.001667
# 25%     0.067545   0.050672
# 50%     0.160902   0.093500
# 75%     0.245950   0.144045
# max     0.331046   0.206936
#
# CLASSIFICATION REPORT OVER ALL CV PREDICTIONS:
#
#                      precision    recall  f1-score   support
#
#    вопрос по оплате       0.01      0.02      0.02      1850
#    жалоба на сервис       0.27      0.11      0.15      1705
#     запрос возврата       0.06      0.04      0.05      1940
#   запрос документов       0.35      0.51      0.42      1660
#        консультация       0.34      0.33      0.33      1945
#     ошибка в данных       0.02      0.01      0.02      2050
# проблема с доступом       0.13      0.12      0.12      1785
#    технический сбой       0.20      0.20      0.20      2065
#
#            accuracy                           0.16     15000
#           macro avg       0.17      0.17      0.16     15000
#        weighted avg       0.17      0.16      0.16     15000
#
#
# CONFUSION MATRIX OVER ALL CV PREDICTIONS:
#
# [[ 45  42 876 137  25 419 186 120]
#  [408 181  15 105  70  99  90 737]
#  [962  29  82 162 212 146 224 123]
#  [122  44  40 847 213 142 197  55]
#  [ 98  92 153 427 644 236 161 134]
#  [702  66  19 261 296  28 323 355]
#  [596  16  16 212 301 280 210 154]
#  [472 203 161 254 160 178 227 410]]

# %% [markdown]
# ## Сохранение

# %%
classification_report_dict = classification_report(
    y_true_cv,
    y_pred_cv,
    zero_division=0,
    output_dict=True,
)
confusion_matrix_values = confusion_matrix(y_true_cv, y_pred_cv)

bundle = {
    'task': 'tickets_category_with_features',
    'model': best_model,
    'model_type': best_model_type,
    'model_params': model_params,
    'preprocessors': preprocessors,
    'config': {
        'text_column': 'message',
        'target_column': 'final_category',
        'id_column': 'ticket_id',
        'categorical_columns': ['product', 'priority'],
        'numeric_columns': ['reopened_count'],
        'feature_order': [
            'word_tfidf',
            'char_tfidf',
            'categorical_one_hot',
            'numeric_scaled',
        ],
        'random_state': RANDOM_STATE,
        'n_splits': N_SPLITS,
        'cv_random_states': CV_RANDOM_STATES,
        'bad_stopwords': bad_stopwords,
        'russian_stopwords': russian_stopwords,
        'clean_text_source': CLEAN_TEXT_SOURCE,
        'morph_analyzer': 'pymorphy3.MorphAnalyzer()',
        'categorical_fill_value': 'unknown',
        'numeric_fill_value': 0,
    },
    'metrics': {
        'cv_results': cv_results_df,
        'accuracy_mean': accuracy_mean,
        'accuracy_std': accuracy_std,
        'macro_f1_mean': macro_f1_mean,
        'macro_f1_std': macro_f1_std,
        'classification_report': classification_report_dict,
        'confusion_matrix': confusion_matrix_values.tolist(),
    },
    'metadata': {
        'data_path': 'nerd_analytics_v25.xlsx',
        'tickets_sheet': 'tickets',
        'chat_history_sheet': 'chat_history',
        'n_rows': len(cat_df),
        'classes': sorted(y_all.unique().tolist()),
        'word_features': preprocessors['word_vectorizer'].transform(cat_df['clean_message']).shape[1],
        'char_features': preprocessors['char_vectorizer'].transform(cat_df['clean_message']).shape[1],
        'categorical_features': preprocessors['encoder'].transform(cat_df[['product', 'priority']]).shape[1],
        'numeric_features': 1,
    },
}

joblib.dump(bundle, 'tickets_categories_with_features.pkl')
print('Saved model bundle to: tickets_categories_with_features.pkl')
print(bundle['metadata'])
# Out:
# Saved model bundle to: tickets_categories_with_features.pkl
# {'data_path': 'nerd_analytics_v25.xlsx', 'tickets_sheet': 'tickets', 'chat_history_sheet': 'chat_history', 'n_rows': 3000, 'classes': ['вопрос по оплате', 'жалоба на сервис', 'запрос возврата', 'запрос документов', 'консультация', 'ошибка в данных', 'проблема с доступом', 'технический сбой'], 'word_features': 148, 'char_features': 1213, 'categorical_features': 9, 'numeric_features': 1}
