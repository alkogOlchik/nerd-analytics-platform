# %% [markdown]
# # Импорты

# %%
# !pip install catboost
# !pip install pymorphy3
# !pip install optuna
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (75.2.0)
# Downloading pymorphy3-2.0.6-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 3.3 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 49.4 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 15.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
import pandas as pd
import numpy as np
import re
from scipy.sparse import hstack
import optuna

import pymorphy3
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    accuracy_score,
)

# %%
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Загрузка и исследование данных

# %%
df = pd.read_excel('nerd_analytics_v25.xlsx', sheet_name='reviews')

# %%
df = df[['id', 'comment', 'sentiment', 'rating', 'keywords_positive', 'keywords_neutral', 'keywords_negative', 'product', 'final_category']]

# %%
df.shape[0]
# Out:
# 1235

# %%
df[['id', 'comment', 'sentiment', 'keywords_positive', 'keywords_neutral', 'keywords_negative', 'product', 'final_category']].describe()
# Out:
#                                           id  \
# count                                   1235
# unique                                  1235
# top     266a542e-a9f3-4127-916e-76e017b10e1b
# freq                                       1
#
#                                          comment sentiment keywords_positive  \
# count                                       1235      1235               815
# unique                                        65         3                29
# top     Ответили быстро, не пришлось долго ждать  positive           приятно
# freq                                          45       770                59
#
#        keywords_neutral keywords_negative               product  \
# count               397               189                  1235
# unique               12                16                     6
# top               целом             долго  аналитический модуль
# freq                 66                69                   249
#
#          final_category
# count              1235
# unique                5
# top     качество ответа
# freq                286

# %%
df.describe()
# Out:
#             rating
# count  1235.000000
# mean      3.710121
# std       1.155714
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1235 non-null   object
#  1   comment            1235 non-null   object
#  2   sentiment          1235 non-null   object
#  3   rating             1235 non-null   int64
#  4   keywords_positive  815 non-null    object
#  5   keywords_neutral   397 non-null    object
#  6   keywords_negative  189 non-null    object
#  7   product            1235 non-null   object
#  8   final_category     1235 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 87.0+ KB

# %%
df['product'].value_counts()
# Out:
# product
# аналитический модуль    249
# платёжный сервис        210
# API интеграция          206
# мобильное приложение    204
# веб-сервис              193
# личный кабинет          173
# Name: count, dtype: int64

# %%
df.isna().sum(), df.duplicated().sum()
# Out:
# (id                      0
#  comment                 0
#  sentiment               0
#  rating                  0
#  keywords_positive     420
#  keywords_neutral      838
#  keywords_negative    1046
#  product                 0
#  final_category          0
#  dtype: int64,
#  np.int64(0))

# %% [markdown]
# # Определение общей тональности отзыва

# %% [markdown]
# ## Подготовка данных

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    770
# neutral     269
# negative    196
# Name: count, dtype: int64

# %%
df1 = df.copy()
RANDOM_STATE = 67

# %%
morph = pymorphy3.MorphAnalyzer()
russian_stopwords = stopwords.words('russian')
bad_stopwords = ['не', 'нет', 'ни', 'без']

russian_stopwords = [
    word for word in russian_stopwords
    if word not in bad_stopwords
]

def clean_text(text):

    text = text.lower()
    text = re.sub(r"http\S+", " ", text)
    text = re.sub(r"www\S+", " ", text)
    text = re.sub(r"@\w+", " ", text)
    text = re.sub(r"[^а-яa-zё\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    words = text.split()
    lemmas = []

    for word in words:
        if word not in russian_stopwords:
            lemma = morph.parse(word)[0].normal_form
            lemmas.append(lemma)

    return " ".join(lemmas)

df1['clean_comment'] = df1['comment'].apply(clean_text)

# %% [markdown]
# ## Перебор моделей и гиперпараметров

# %%
sent_df = df1[['clean_comment', 'product', 'final_category', 'sentiment']].copy()
X_all = sent_df[['clean_comment', 'product', 'final_category']]
y_all = sent_df['sentiment']
groups_all = sent_df['clean_comment']

N_SPLITS = 5
CV_RANDOM_STATES = [RANDOM_STATE, 101, 202, 303, 404]


def build_features(train_part, valid_part):
    word_vectorizer = TfidfVectorizer(max_features=30000, ngram_range=(1, 2), min_df=2, max_df=0.95)
    char_vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), max_features=20000)
    try:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=True)
    except TypeError:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse=True)

    X_train_word = word_vectorizer.fit_transform(train_part['clean_comment'])
    X_valid_word = word_vectorizer.transform(valid_part['clean_comment'])
    X_train_char = char_vectorizer.fit_transform(train_part['clean_comment'])
    X_valid_char = char_vectorizer.transform(valid_part['clean_comment'])
    X_train_cat = encoder.fit_transform(train_part[['product', 'final_category']])
    X_valid_cat = encoder.transform(valid_part[['product', 'final_category']])

    return hstack([X_train_word, X_train_char, X_train_cat]), hstack([X_valid_word, X_valid_char, X_valid_cat])


def build_model_and_params(trial):
    model_type = trial.suggest_categorical('model_type', ['SVC', 'LogReg', 'CatBoost'])

    if model_type == 'SVC':
        params = {
            'C': trial.suggest_float('svc_C', 0.1, 5.0, log=True),
            'kernel': trial.suggest_categorical('svc_kernel', ['linear', 'rbf']),
            'gamma': 'scale',
            'class_weight': trial.suggest_categorical('svc_class_weight', [None, 'balanced']),
        }
        return model_type, params

    if model_type == 'LogReg':
        params = {
            'C': trial.suggest_float('lr_C', 0.1, 10.0, log=True),
            'solver': trial.suggest_categorical('lr_solver', ['lbfgs', 'saga']),
            'class_weight': trial.suggest_categorical('lr_class_weight', [None, 'balanced']),
            'max_iter': 3000,
            'n_jobs': -1,
            'random_state': RANDOM_STATE,
        }
        return model_type, params

    params = {
        'iterations': trial.suggest_int('cb_iterations', 200, 900),
        'depth': trial.suggest_int('cb_depth', 4, 10),
        'learning_rate': trial.suggest_float('cb_learning_rate', 0.01, 0.2, log=True),
        'l2_leaf_reg': trial.suggest_int('cb_l2_leaf_reg', 1, 12),
        'random_strength': trial.suggest_float('cb_random_strength', 1.0, 10.0),
        'bagging_temperature': trial.suggest_float('cb_bagging_temperature', 0.0, 10.0),
        'border_count': trial.suggest_int('cb_border_count', 64, 255),
        'auto_class_weights': trial.suggest_categorical('cb_auto_class_weights', ['Balanced', None]),
    }
    return model_type, params


def make_model(model_type, model_params):
    if model_type == 'SVC':
        return SVC(**model_params)

    if model_type == 'LogReg':
        return LogisticRegression(**model_params)

    return CatBoostClassifier(
        **model_params,
        loss_function='MultiClass',
        eval_metric='TotalF1',
        random_state=RANDOM_STATE,
        task_type='GPU',
        verbose=False,
    )


def get_cv_scores(model_type, model_params, data, cv_random_states):
    fold_scores = []

    for cv_seed in cv_random_states:
        cv = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=cv_seed)

        for tr_fold_idx, val_fold_idx in cv.split(
            data[['clean_comment', 'product', 'final_category']],
            data['sentiment'],
            groups=data['clean_comment'],
        ):
            tr_part = data.iloc[tr_fold_idx]
            val_part = data.iloc[val_fold_idx]

            X_tr, X_val = build_features(tr_part, val_part)
            y_tr = tr_part['sentiment']
            y_val = val_part['sentiment']

            model = make_model(model_type, model_params)
            model.fit(X_tr, y_tr, verbose=False) if model_type == 'CatBoost' else model.fit(X_tr, y_tr)
            pred = model.predict(X_val).flatten() if model_type == 'CatBoost' else model.predict(X_val)

            fold_scores.append(f1_score(y_val, pred, average='macro'))

    return fold_scores


def objective(trial):
    model_type, model_params = build_model_and_params(trial)
    fold_scores = get_cv_scores(model_type, model_params, sent_df, CV_RANDOM_STATES)
    return float(np.mean(fold_scores))


sampler = optuna.samplers.TPESampler(seed=RANDOM_STATE)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=40)

print('BEST MEAN CV SCORE:')
print(study.best_value)
print('BEST PARAMS:')
print(study.best_params)
# Out:
# [I 2026-05-25 15:42:46,749] A new study created in memory with name: no-name-5863d8a5-f4c2-4381-8629-dc6f5e7b1a5d
# [I 2026-05-25 15:43:22,388] Trial 0 finished with value: 0.2910982925661927 and parameters: {'model_type': 'LogReg', 'lr_C': 0.4604512348683669, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 0 with value: 0.2910982925661927.
# [I 2026-05-25 15:45:06,219] Trial 1 finished with value: 0.3474627586124817 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 614, 'cb_depth': 5, 'cb_learning_rate': 0.025699473441646203, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 4.152879163423533, 'cb_bagging_temperature': 2.5724281189423115, 'cb_border_count': 66, 'cb_auto_class_weights': None}. Best is trial 1 with value: 0.3474627586124817.
# [I 2026-05-25 15:45:41,253] Trial 2 finished with value: 0.29654243551970555 and parameters: {'model_type': 'LogReg', 'lr_C': 1.1463487962934191, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.3474627586124817.
# [I 2026-05-25 15:45:46,619] Trial 3 finished with value: 0.3217441894192591 and parameters: {'model_type': 'SVC', 'svc_C': 0.4008812672862209, 'svc_kernel': 'linear', 'svc_class_weight': 'balanced'}. Best is trial 1 with value: 0.3474627586124817.
# [I 2026-05-25 15:48:15,191] Trial 4 finished with value: 0.33907195101919213 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 232, 'cb_depth': 10, 'cb_learning_rate': 0.030345078436747795, 'cb_l2_leaf_reg': 9, 'cb_random_strength': 3.465376314384963, 'cb_bagging_temperature': 2.49045064855544, 'cb_border_count': 122, 'cb_auto_class_weights': None}. Best is trial 1 with value: 0.3474627586124817.
# [I 2026-05-25 15:48:57,103] Trial 5 finished with value: 0.3051476466822956 and parameters: {'model_type': 'LogReg', 'lr_C': 7.146126032532701, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 1 with value: 0.3474627586124817.
# [I 2026-05-25 15:50:20,868] Trial 6 finished with value: 0.3782968524553674 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 500, 'cb_depth': 5, 'cb_learning_rate': 0.015759505780658597, 'cb_l2_leaf_reg': 6, 'cb_random_strength': 8.397080924885024, 'cb_bagging_temperature': 6.379478291475213, 'cb_border_count': 255, 'cb_auto_class_weights': 'Balanced'}. Best is trial 6 with value: 0.3782968524553674.
# [I 2026-05-25 15:51:04,958] Trial 7 finished with value: 0.3014538762345802 and parameters: {'model_type': 'LogReg', 'lr_C': 3.4672119216322, 'lr_solver': 'saga', 'lr_class_weight': 'balanced'}. Best is trial 6 with value: 0.3782968524553674.
# [I 2026-05-25 15:52:12,996] Trial 8 finished with value: 0.34237708508734693 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 317, 'cb_depth': 6, 'cb_learning_rate': 0.1102255521271414, 'cb_l2_leaf_reg': 10, 'cb_random_strength': 2.325154165332503, 'cb_bagging_temperature': 2.3806972152099926, 'cb_border_count': 153, 'cb_auto_class_weights': 'Balanced'}. Best is trial 6 with value: 0.3782968524553674.
# [I 2026-05-25 15:52:21,176] Trial 9 finished with value: 0.31861308805985067 and parameters: {'model_type': 'SVC', 'svc_C': 0.10852754990405093, 'svc_kernel': 'linear', 'svc_class_weight': None}. Best is trial 6 with value: 0.3782968524553674.
# [I 2026-05-25 15:54:02,008] Trial 10 finished with value: 0.3855067507154245 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 819, 'cb_depth': 4, 'cb_learning_rate': 0.01053510870871155, 'cb_l2_leaf_reg': 4, 'cb_random_strength': 9.798149440633491, 'cb_bagging_temperature': 8.715751676028873, 'cb_border_count': 242, 'cb_auto_class_weights': 'Balanced'}. Best is trial 10 with value: 0.3855067507154245.
# [I 2026-05-25 15:55:47,871] Trial 11 finished with value: 0.3988039481179709 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 866, 'cb_depth': 4, 'cb_learning_rate': 0.011419726624085608, 'cb_l2_leaf_reg': 4, 'cb_random_strength': 9.999254706507802, 'cb_bagging_temperature': 9.360678129834476, 'cb_border_count': 248, 'cb_auto_class_weights': 'Balanced'}. Best is trial 11 with value: 0.3988039481179709.
# [I 2026-05-25 15:57:35,801] Trial 12 finished with value: 0.39415829435368005 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 890, 'cb_depth': 4, 'cb_learning_rate': 0.010479227729363405, 'cb_l2_leaf_reg': 2, 'cb_random_strength': 9.972806355207707, 'cb_bagging_temperature': 9.84684767381875, 'cb_border_count': 252, 'cb_auto_class_weights': 'Balanced'}. Best is trial 11 with value: 0.3988039481179709.
# [I 2026-05-25 16:02:11,044] Trial 13 finished with value: 0.40323756246696263 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 891, 'cb_depth': 8, 'cb_learning_rate': 0.010508036248280934, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 7.240860204670903, 'cb_bagging_temperature': 9.846538937563892, 'cb_border_count': 205, 'cb_auto_class_weights': 'Balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:05:58,848] Trial 14 finished with value: 0.4013990829255229 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 724, 'cb_depth': 8, 'cb_learning_rate': 0.06178565523709494, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 6.897874692963148, 'cb_bagging_temperature': 7.127431969965431, 'cb_border_count': 206, 'cb_auto_class_weights': 'Balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:09:37,527] Trial 15 finished with value: 0.3954923148637143 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 696, 'cb_depth': 8, 'cb_learning_rate': 0.08051418003310586, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 6.541878321540621, 'cb_bagging_temperature': 6.604191358019787, 'cb_border_count': 196, 'cb_auto_class_weights': 'Balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:09:46,622] Trial 16 finished with value: 0.3195341373537493 and parameters: {'model_type': 'SVC', 'svc_C': 4.4012214498862505, 'svc_kernel': 'rbf', 'svc_class_weight': 'balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:13:28,128] Trial 17 finished with value: 0.4020421530931976 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 719, 'cb_depth': 8, 'cb_learning_rate': 0.05754009789667345, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 6.434655064645184, 'cb_bagging_temperature': 7.422809037598757, 'cb_border_count': 194, 'cb_auto_class_weights': 'Balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:18:26,915] Trial 18 finished with value: 0.3660021267052324 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 747, 'cb_depth': 9, 'cb_learning_rate': 0.19684265866720393, 'cb_l2_leaf_reg': 7, 'cb_random_strength': 5.36153755682447, 'cb_bagging_temperature': 4.666362252941676, 'cb_border_count': 191, 'cb_auto_class_weights': None}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:18:35,906] Trial 19 finished with value: 0.3195341373537493 and parameters: {'model_type': 'SVC', 'svc_C': 4.1246908811256375, 'svc_kernel': 'rbf', 'svc_class_weight': None}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:20:48,860] Trial 20 finished with value: 0.3953946074422435 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 550, 'cb_depth': 7, 'cb_learning_rate': 0.041862681521141004, 'cb_l2_leaf_reg': 12, 'cb_random_strength': 7.355363295307822, 'cb_bagging_temperature': 7.87525459958623, 'cb_border_count': 162, 'cb_auto_class_weights': 'Balanced'}. Best is trial 13 with value: 0.40323756246696263.
# [I 2026-05-25 16:24:38,616] Trial 21 finished with value: 0.41242219186993173 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 738, 'cb_depth': 8, 'cb_learning_rate': 0.06782020527194381, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 6.180504747085828, 'cb_bagging_temperature': 7.255976241427066, 'cb_border_count': 207, 'cb_auto_class_weights': 'Balanced'}. Best is trial 21 with value: 0.41242219186993173.
# [I 2026-05-25 16:28:37,157] Trial 22 finished with value: 0.3857466611997853 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 780, 'cb_depth': 8, 'cb_learning_rate': 0.05714150392774734, 'cb_l2_leaf_reg': 1, 'cb_random_strength': 5.506795295483907, 'cb_bagging_temperature': 5.715399714633709, 'cb_border_count': 215, 'cb_auto_class_weights': 'Balanced'}. Best is trial 21 with value: 0.41242219186993173.
# [I 2026-05-25 16:33:23,187] Trial 23 finished with value: 0.4185546038473055 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 655, 'cb_depth': 9, 'cb_learning_rate': 0.10360092983024889, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 7.925080818531179, 'cb_bagging_temperature': 8.236969249945856, 'cb_border_count': 172, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:40:05,402] Trial 24 finished with value: 0.4119327604430809 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 608, 'cb_depth': 10, 'cb_learning_rate': 0.12377790081325231, 'cb_l2_leaf_reg': 4, 'cb_random_strength': 8.001376203991363, 'cb_bagging_temperature': 8.446905211755595, 'cb_border_count': 162, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:46:43,328] Trial 25 finished with value: 0.40268892307257104 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 606, 'cb_depth': 10, 'cb_learning_rate': 0.12909122098414927, 'cb_l2_leaf_reg': 5, 'cb_random_strength': 8.465748258893349, 'cb_bagging_temperature': 8.26347575019829, 'cb_border_count': 157, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:49:41,843] Trial 26 finished with value: 0.35832318306860567 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 429, 'cb_depth': 9, 'cb_learning_rate': 0.116422484980631, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 8.41982520624924, 'cb_bagging_temperature': 4.713679990381643, 'cb_border_count': 119, 'cb_auto_class_weights': None}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:54:20,907] Trial 27 finished with value: 0.4040053238775755 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 634, 'cb_depth': 9, 'cb_learning_rate': 0.18282738913093385, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 5.359318960128921, 'cb_bagging_temperature': 8.71554277017913, 'cb_border_count': 175, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:54:29,191] Trial 28 finished with value: 0.3185182967801423 and parameters: {'model_type': 'SVC', 'svc_C': 0.7478217108024773, 'svc_kernel': 'rbf', 'svc_class_weight': None}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:54:36,299] Trial 29 finished with value: 0.3045905360126743 and parameters: {'model_type': 'LogReg', 'lr_C': 0.15321289404723024, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:54:39,655] Trial 30 finished with value: 0.30097519170920434 and parameters: {'model_type': 'LogReg', 'lr_C': 0.13376343290267292, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 16:59:21,581] Trial 31 finished with value: 0.4083200138602804 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 634, 'cb_depth': 9, 'cb_learning_rate': 0.18884907693006772, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 5.605279811960271, 'cb_bagging_temperature': 8.612715564137595, 'cb_border_count': 174, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:06:37,672] Trial 32 finished with value: 0.3845454696126188 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 665, 'cb_depth': 10, 'cb_learning_rate': 0.14793657482782457, 'cb_l2_leaf_reg': 4, 'cb_random_strength': 4.39456383712045, 'cb_bagging_temperature': 8.009385529145966, 'cb_border_count': 137, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:10:36,884] Trial 33 finished with value: 0.40822486061617164 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 534, 'cb_depth': 9, 'cb_learning_rate': 0.08962378825458266, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 7.902305723640775, 'cb_bagging_temperature': 8.857817220817381, 'cb_border_count': 176, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:14:05,823] Trial 34 finished with value: 0.3827666256973716 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 483, 'cb_depth': 9, 'cb_learning_rate': 0.0971143476185896, 'cb_l2_leaf_reg': 5, 'cb_random_strength': 5.914744739761954, 'cb_bagging_temperature': 5.847111226307849, 'cb_border_count': 175, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:20:22,621] Trial 35 finished with value: 0.3741322716680255 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 591, 'cb_depth': 10, 'cb_learning_rate': 0.15519386223319517, 'cb_l2_leaf_reg': 2, 'cb_random_strength': 8.91062188372564, 'cb_bagging_temperature': 6.923830630212002, 'cb_border_count': 226, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:23:02,145] Trial 36 finished with value: 0.40533671475816924 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 660, 'cb_depth': 7, 'cb_learning_rate': 0.08289362370428234, 'cb_l2_leaf_reg': 2, 'cb_random_strength': 7.555524030777279, 'cb_bagging_temperature': 7.735965251780543, 'cb_border_count': 139, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:23:08,105] Trial 37 finished with value: 0.32454373313498003 and parameters: {'model_type': 'LogReg', 'lr_C': 1.1262107545263966, 'lr_solver': 'lbfgs', 'lr_class_weight': None}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:28:30,256] Trial 38 finished with value: 0.3401631911370696 and parameters: {'model_type': 'CatBoost', 'cb_iterations': 787, 'cb_depth': 9, 'cb_learning_rate': 0.1476465522529773, 'cb_l2_leaf_reg': 5, 'cb_random_strength': 6.095725985826373, 'cb_bagging_temperature': 3.6272332844546105, 'cb_border_count': 183, 'cb_auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.4185546038473055.
# [I 2026-05-25 17:28:35,245] Trial 39 finished with value: 0.3217441894192591 and parameters: {'model_type': 'SVC', 'svc_C': 1.0932210875524546, 'svc_kernel': 'linear', 'svc_class_weight': 'balanced'}. Best is trial 23 with value: 0.4185546038473055.
# BEST MEAN CV SCORE:
# 0.4185546038473055
# BEST PARAMS:
# {'model_type': 'CatBoost', 'cb_iterations': 655, 'cb_depth': 9, 'cb_learning_rate': 0.10360092983024889, 'cb_l2_leaf_reg': 3, 'cb_random_strength': 7.925080818531179, 'cb_bagging_temperature': 8.236969249945856, 'cb_border_count': 172, 'cb_auto_class_weights': 'Balanced'}

# %% [markdown]
# ## Обучение лучшей модели

# %%
best_params = dict(study.best_params)
best_model_type = best_params.pop('model_type')

if best_model_type == 'SVC':
    model_params = {
        'C': best_params['svc_C'],
        'kernel': best_params['svc_kernel'],
        'gamma': 'scale',
        'class_weight': best_params['svc_class_weight'],
    }
elif best_model_type == 'LogReg':
    model_params = {
        'C': best_params['lr_C'],
        'solver': best_params['lr_solver'],
        'class_weight': best_params['lr_class_weight'],
        'max_iter': 3000,
        'n_jobs': -1,
        'random_state': RANDOM_STATE,
    }
else:
    model_params = {
        'iterations': best_params['cb_iterations'],
        'depth': best_params['cb_depth'],
        'learning_rate': best_params['cb_learning_rate'],
        'l2_leaf_reg': best_params['cb_l2_leaf_reg'],
        'random_strength': best_params['cb_random_strength'],
        'bagging_temperature': best_params['cb_bagging_temperature'],
        'border_count': best_params['cb_border_count'],
        'auto_class_weights': best_params['cb_auto_class_weights'],
    }

cv_results = []
y_true_all = []
y_pred_all = []

for cv_seed in CV_RANDOM_STATES:
    cv = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=cv_seed)

    for fold, (tr_fold_idx, val_fold_idx) in enumerate(
        cv.split(X_all, y_all, groups=groups_all),
        start=1,
    ):
        tr_part = sent_df.iloc[tr_fold_idx]
        val_part = sent_df.iloc[val_fold_idx]

        X_tr, X_val = build_features(tr_part, val_part)
        y_tr = tr_part['sentiment']
        y_val = val_part['sentiment']

        model = make_model(best_model_type, model_params)
        model.fit(X_tr, y_tr, verbose=False) if best_model_type == 'CatBoost' else model.fit(X_tr, y_tr)
        pred = model.predict(X_val).flatten() if best_model_type == 'CatBoost' else model.predict(X_val)

        cv_results.append({
            'seed': cv_seed,
            'fold': fold,
            'accuracy': accuracy_score(y_val, pred),
            'macro_f1': f1_score(y_val, pred, average='macro'),
        })
        y_true_all.extend(y_val)
        y_pred_all.extend(pred)

cv_results_df = pd.DataFrame(cv_results)
y_true_cv = pd.Series(y_true_all, name='true')
y_pred_cv = pd.Series(y_pred_all, name='pred')

X_full, _ = build_features(sent_df, sent_df)
best_model = make_model(best_model_type, model_params)
best_model.fit(X_full, y_all, verbose=False) if best_model_type == 'CatBoost' else best_model.fit(X_full, y_all)
# Out:
# CatBoostClassifier(auto_class_weights='Balanced', bagging_temperature=8.236969249945856, border_count=172, depth=9, eval_metric='TotalF1', iterations=655, l2_leaf_reg=3, learning_rate=0.10360092983024889, loss_function='MultiClass', random_state=67, random_strength=7.925080818531179, task_type='GPU', verbose=False)

# %%
accuracy_mean = cv_results_df['accuracy'].mean()
accuracy_std = cv_results_df['accuracy'].std()
macro_f1_mean = cv_results_df['macro_f1'].mean()
macro_f1_std = cv_results_df['macro_f1'].std()

print(f'\nBest model type: {best_model_type}')
print(f'CV seeds: {CV_RANDOM_STATES}')
print(f'Accuracy: {accuracy_mean:.4f} +/- {accuracy_std:.4f}')
print(f'Macro F1: {macro_f1_mean:.4f} +/- {macro_f1_std:.4f}')
print('\nFOLD METRICS SUMMARY:\n')
print(cv_results_df[['accuracy', 'macro_f1']].describe())
print('\nCLASSIFICATION REPORT OVER ALL CV PREDICTIONS:\n')
print(classification_report(y_true_cv, y_pred_cv))
print('\nCONFUSION MATRIX OVER ALL CV PREDICTIONS:\n')
print(confusion_matrix(y_true_cv, y_pred_cv))
# Out:
# Best model type: CatBoost
# CV seeds: [67, 101, 202, 303, 404]
# Accuracy: 0.5078 +/- 0.1195
# Macro F1: 0.4151 +/- 0.1072
#
# FOLD METRICS SUMMARY:
#
#         accuracy   macro_f1
# count  25.000000  25.000000
# mean    0.507825   0.415060
# std     0.119480   0.107236
# min     0.224189   0.150418
# 25%     0.441341   0.343376
# 50%     0.527660   0.454406
# 75%     0.610714   0.484511
# max     0.684015   0.585410
#
# CLASSIFICATION REPORT OVER ALL CV PREDICTIONS:
#
#               precision    recall  f1-score   support
#
#     negative       0.26      0.49      0.34       980
#      neutral       0.39      0.27      0.32      1345
#     positive       0.68      0.60      0.63      3850
#
#     accuracy                           0.51      6175
#    macro avg       0.44      0.45      0.43      6175
# weighted avg       0.55      0.51      0.52      6175
#
#
# CONFUSION MATRIX OVER ALL CV PREDICTIONS:
#
# [[ 481   73  426]
#  [ 313  357  675]
#  [1068  489 2293]]
